# %%
def sum(a,b):
    return a+b
a,b = map(int,input().split())
sum(a,b)
print(sum(a,b))
# Out:
# 7

# %%
def one_to_n(n):
    arrange = []
    for i in range(1,n+1):
        arrange.append(str(i))
    print(" ".join(arrange))
n = int(input("Nhập vào số nguyên n"))
one_to_n(n)
# Out:
# 1 2 3 4 5 6

# %%
dictionary = {"Name":"Long","Age":30,"Nationality":"Vietnamese"}
print(dictionary["Age"], dictionary["Name"],dictionary["Nationality"])
# Out:
# 30 Long Vietnamese

# %%
# Out:
# 54321
