# %%
#W2A7
A = ((13 ** 2) * 3) + 5
B = 13**2*3 + 5
print(A, B)
# Out:
# 512 512

# %%
#W2A8
temperature = float(input("Nhiet do celsius"))
F = 9/5*temperature +32
print(F)
# Out:
# 66.2

# %%
#W2A9
value = float(input("tien dong ho: "))
T = value + value*0.3 + value*0.1 + 10
print(round(T, 2))
# Out:
# 18.87

# %%
#W2A10
name  = input().split()
reverse = list(reversed(name))
print("Hello ", reverse)
# Out:
# Hello  ['nigga', 'thao', 'longg']

# %%
#W2A11
Hours = float(input())
Minutes = float(input())
Trans = Hours*3600 + Minutes*60
print("giây:", Trans)
# Out:
# giây: 181800.0

# %%
#W2A12
length = int(input())
sosticker = length**2*6
print('mieng dan sticker: ', sosticker)
# Out:
# mieng dan sticker:  24

# %%
#W2A13
a,b = map(float, input().split())
x = a*b
print("ketqua: ", round(x))
# Out:
# ketqua:  6

# %%
#W2A14
a = int(input("Nhập a: "))
b = int(input("Nhập b: "))
print("Sau khi đổi: a =", a, ", b =", b)

# %%
#W2A15
Z = int(input())
sosao = Z*6
print(sosao)
# Out:
# 36

# %%
#W2A16
print("Spring\nSummer\nAutumn\nWinter")
# Out:
# Spring
# Summer
# Autumn
# Winter

# %%
#W2A17
print("#")
print("##")
print("###")
# Out:
# #
# ##
# ###

# %%
#W2A18
print("### ##   ### ### ")
print(" #  #  #  #   #")
print(" #  #   # #   #")
print(" #  #  #  #   #")
print(" #  ##    #   #")
# Out:
# ### ##   ### ###
#  #  #  #  #   #
#  #  #   # #   #
#  #  #  #  #   #
#  #  ##    #   #

# %%
#W2A19
print("Monday")
print("Tuesday")
print("Wednesday")
print("Thursday")
print("Friday")
print("Saturday")
print("Sunday")
# Out:
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday

# %%
#W2A20
print("January\nFebruary\nMarch\nApril\nMay\nJune\nAugust\nSeptember\nOctober\nNovember\nDecember")
# Out:
# January
# February
# March
# April
# May
# June
# August
# September
# October
# November
# December

# %%
#W2A21
print("Hello, world")
print("Hello, world")
print("Hello, world")
print("Hello, world")
print("Hello, world")
print("Hello, world")
print("Hello, world")
print("Hello, world")
print("Hello, world")
print("Hello, world")
