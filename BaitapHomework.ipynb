# %%
#Bai 1
H = float(input())
O = 2*H
print("ket qua ", O)
# Out:
# ket qua  4.0

# %%
#Bai 2
print("chieu rong")
a = float(input())
print("chieu dai")
b = float(input())
S_hcn = a*b
S_htron = 3.14*((a/2)**2)
S_cay = S_hcn - S_htron
print("dien tich trong cay: ", round(S_cay,2))
# Out:
# chieu rong
# chieu dai
# dien tich trong cay:  116.41

# %%
#Bai 3
C = str(input())
D= ord(C)
if D > 96:
    print(C.upper())
else:
    print(C.lower())
# Out:
# h

# %%
#Bai 4
Alphabet = str(input())
U = ord(Alphabet)
if 64< U < 91:
    print("{Alphabet} la ki tu alphabet")
elif 96< U <123:
    print("{Alphabet} la ki tu alphabet")
else:
    print("{Alphabet} khong la ki tu alphabet")
# Out:
# {Alphabet} khong la ki tu alphabet

# %%
#Bai 5
#Nhapchucaiinhoa
A = str(input())
print(A.lower(),A)
# Out:
# h H

# %%
#Bai 6
import math
a,b,c = map(float,input().split())
p = (a+b+c)/2
S_binhphuong = p*(p-a)*(p-b)*(p-c)
S = math.sqrt(S_binhphuong)
if a+b>c and a+c>b and b+c>a:
    print("la tam giac")
    print(round(S, 1))
else:
    print("ko phai tam giac")
# Out:
# la tam giac
# 9.9

# %%
#Bai 7
I = str(input())
if len(I) >= 20:
    print(I[4])
    print(I[8])
else:
    print("so ko du")
# Out:
# 5
# 9

# %%
#Bai 8
#Nhap ten chu ho 1
Ho_1 = str(input())
#Nhap so dien thang nay va thang truoc
Thangnay = int(input())
Thangtruoc = int(input())
Total = (Thangnay-Thangtruoc)*1984 + (Thangnay-Thangtruoc)*1984*0.08
print(round(Total))
# Out:
# 107136
