# %%
#W3A5+W3A4
a,b = map(int,input().split())
c = a/b
print(round(c))
# Out:
# 1

# %%
#W3A6
x = int(input("Nhập vào số nguyên:"))
if x%2 == 0:
    print("Đây là số chẵn")
else:
    print("Đây là số lẻ")
# Out:
# Đây là số chẵn

# %%
#W3A7
a = int(input("Nhập vào số nguyên a:"))
b = int(input("Nhập vào số nguyên b:"))
if a<0 and b<0:
    print("Yes đây là số âm")
elif a ==0:
    print("Đây là số 0")
elif a>0 or b>0:
    print("a hoặc b là số dương")
else:
    print("No đây là số dương")
# Out:
# Đây là số 0

# %%
#W3A8
a = str(input("Nhập vào 1 từ a:"))
b = str(input("Nhập vào 1 từ b:"))
if len(a)>len(b):
    print("a daì hơn b")
elif len(a)==len(b):
    print("a,b bằng nhau về độ dài")
else:
    print("b dài hơn a")
# Out:
# a,b bằng nhau về độ dài

# %%
#W3A9
a = int(input("Nhập vào cạnh thứ 1:"))
b = int(input("Nhập vào cạnh thứ 2:"))
c = int(input("Nhập vào cạnh thứ 3:"))
if a+b>c and a+c>b and b+c>a:
    print("Là tam giác")
else:
    print("Khong la tam giac")

# %%
#WA10
a = list(map(int,input().split()))
maxnumber = a[0]
for n in a:
    if n > maxnumber:
        maxnumber = n
print(maxnumber)
#Cách dùng hàm max
a = list(map(int,input().split()))
print(max(a))
# Out:
# 5
# 11

# %%
#W3A11
a = int(input("Nhập vào cạnh thứ 1:"))
b = int(input("Nhập vào cạnh thứ 2:"))
c = int(input("Nhập vào cạnh thứ 3:"))
if a+b>c and a+c>b and b+c>a:
    print("Là tam giác")
    if a==b==c:
        print("Là tam giác đều")
    elif a==b or a==c or b==c:
        print("Là tam giác cân")
else:
    print("Không phải tam giác")
# Out:
# Là tam giác
# Là tam giác cân

# %%
#WA12
year = int(input("Nhap vao so nam:"))
if year%4 ==0 and year%100 !=0:
    print("Day la nam nhuan")
else:
    print("Day ko phai nam nhuan")
# Out:
# Day ko phai nam nhuan

# %%
#W3A14
a,b = map(float, input("Nhap vao so nguyen").split()) #ax+b = 0
if a ==0:
    if b==0:
        print("Vô số nghiệm")
    else:
        print("Vô nghiệm")
else:
    print("Phương trình có nghiệm duy nhất là:", -b/a)
# Out:
# Phương trình có nghiệm duy nhất là: -0.0

# %%
#3A15
Score = float(input("Nhap vao so diem"))
if Score>= 8:
    print("Gioi")
elif Score >=6.5:
    print("Kha")
elif Score >=5:
    print("Trung binh")
else:
    print("Yeu")
# Out:
# Yeu

# %%
#W3A16
a = float(input("nhapmotsothapphan"))
b = a%1
hamtronlen = 1-b + a
hamtronxuong = a - b
if b>=0.5:
    print(hamtronlen)
else: 
    print(hamtronxuong)
# Out:
# 6.0

# %%
#W3A17
a,b,c,d = map(int,input().split())
congboiab = b/a
congboicd = d/c
congboibc = c/b
if congboiab == congboicd == congboibc:
    print("tao thanh cap so nhan voi cong boi la:", congboiab)
else:
    print("Khong phai cong boi")
# Out:
# tao thanh cap so nhan voi cong boi la: 3.0
